# %% [markdown]
# <a href="https://colab.research.google.com/github/Viktoriia-Osmanova/Data-Science/blob/main/Python_DS_HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

import pandas as pd

# Використання відносного шляху до файлу
file_path = '/content/drive/My Drive/Colab Notebooks/Housing.csv'


# Завантажимо дані з файлу
df = pd.read_csv(file_path)

# Подивимося на перші кілька рядків датафрейму
df.head()
# Out:
# Mounted at /content/drive
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Вибираємо необхідні колонки для побудови моделі
X = df[['area', 'bedrooms', 'bathrooms']].values
y = df['price'].values

# %%
import numpy as np

def hypothesis(X, w):
    return np.dot(X, w)

# %%
def compute_loss(X, y, w):

    m = len(y)
    predictions = hypothesis(X, w)
    loss = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return loss

# %%
def gradient_step(X, y, w, alpha):

    m = len(y)
    predictions = hypothesis(X, w)
    gradient = (1 / m) * np.dot(X.T, (predictions - y))
    w -= alpha * gradient
    return w

# %%
from sklearn.preprocessing import StandardScaler

# Нормалізуємо лише числові характеристики (без стовпчика з одиницями)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[:, 1:])

# Додаємо стовпчик з одиницями знову після нормалізації
X_scaled = np.hstack((np.ones((X_scaled.shape[0], 1)), X_scaled))

# %%
# Ініціалізуємо ваги випадковими значеннями
w = np.random.rand(X_scaled.shape[1])

# Задаємо кількість ітерацій та менший коефіцієнт навчання
iterations = 10000
alpha = 0.001  # Зменшений коефіцієнт навчання

# Виконуємо градієнтний спуск
for i in range(iterations):
    w = gradient_step(X_scaled, y, w, alpha)

# Остаточні ваги
print("Отримані параметри w:", w)

# Остаточна функція втрат
final_loss = compute_loss(X_scaled, y, w)
print("Остаточна функція втрат:", final_loss)
# Out:
# Отримані параметри w: [4766513.91863471  821197.96115511  300302.25392208  695511.07743393]
# Остаточна функція втрат: 895585108023.7971

# %%
# Вибираємо необхідні колонки для побудови моделі
X = df[['area', 'bedrooms', 'bathrooms']].values
y = df['price'].values

# Додаємо стовпчик з одиницями для вільного члену (w0)
X = np.hstack((np.ones((X.shape[0], 1)), X))

# Ініціалізуємо ваги випадковими значеннями
w = np.random.rand(X.shape[1])

# Задаємо кількість ітерацій та коефіцієнт навчання
iterations = 10000
alpha = 0.001

# Виконуємо градієнтний спуск
for i in range(iterations):
    w = gradient_step(X, y, w, alpha)

# Остаточні ваги
print("Отримані параметри w:", w)

# Остаточна функція втрат
final_loss = compute_loss(X, y, w)
print("Остаточна функція втрат:", final_loss)
# Out:
# Отримані параметри w: [nan nan nan nan]
# Остаточна функція втрат: nan
# <ipython-input-29-1fc2c73e5fda>:35: RuntimeWarning: invalid value encountered in subtract
#   w -= alpha * gradient

# %%
# Аналітичне рішення (Метод найменших квадратів)
w_analytical = np.linalg.inv(X.T @ X) @ X.T @ y

print("Аналітичні параметри w:", w_analytical)

# Обчислимо функцію втрат для аналітичного рішення
loss_analytical = compute_loss(X, y, w_analytical)
print("Функція втрат для аналітичного рішення:", loss_analytical)
# Out:
# Аналітичні параметри w: [-1.73171608e+05  3.78762754e+02  4.06820034e+05  1.38604950e+06]
# Функція втрат для аналітичного рішення: 895585024988.6597

# %%
print("Різниця між параметрами:", np.abs(w - w_analytical))
print("Різниця у функції втрат:", np.abs(final_loss - loss_analytical))
# Out:
# Різниця між параметрами: [nan nan nan nan]
# Різниця у функції втрат: nan

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Завантажимо дані з файлу
##df = pd.read_csv('Housing.csv')

# Вибираємо необхідні колонки для побудови моделі
X = df[['area', 'bedrooms', 'bathrooms']].values
y = df['price'].values

# Додаємо стовпчик з одиницями для вільного члену (w0)
X = np.hstack((np.ones((X.shape[0], 1)), X))

# Нормалізуємо числові характеристики (без стовпчика з одиницями)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[:, 1:])

# Додаємо стовпчик з одиницями після нормалізації
X_scaled = np.hstack((np.ones((X_scaled.shape[0], 1)), X_scaled))

def hypothesis(X, w):
    return np.dot(X, w)

def compute_loss(X, y, w):
    m = len(y)
    predictions = hypothesis(X, w)
    loss = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return loss

def gradient_step(X, y, w, alpha):
    m = len(y)
    predictions = hypothesis(X, w)
    gradient = (1 / m) * np.dot(X.T, (predictions - y))
    w -= alpha * gradient
    return w

# Ініціалізуємо ваги випадковими значеннями
w = np.random.rand(X_scaled.shape[1])

# Задаємо кількість ітерацій та менший коефіцієнт навчання
iterations = 10000
alpha = 0.001  # Зменшений коефіцієнт навчання

# Виконуємо градієнтний спуск
for i in range(iterations):
    w = gradient_step(X_scaled, y, w, alpha)

# Остаточні ваги
print("Отримані параметри w:", w)

# Остаточна функція втрат
final_loss = compute_loss(X_scaled, y, w)
print("Остаточна функція втрат:", final_loss)

# Аналітичне рішення (Метод найменших квадратів)
w_analytical = np.linalg.inv(X_scaled.T @ X_scaled) @ X_scaled.T @ y

print("Аналітичні параметри w:", w_analytical)

# Обчислимо функцію втрат для аналітичного рішення
loss_analytical = compute_loss(X_scaled, y, w_analytical)
print("Функція втрат для аналітичного рішення:", loss_analytical)

# Порівняння результатів
print("Різниця між параметрами:", np.abs(w - w_analytical))
print("Різниця у функції втрат:", np.abs(final_loss - loss_analytical))
# Out:
# Отримані параметри w: [4766513.91860447  821197.96106809  300302.25350104  695511.07790042]
# Остаточна функція втрат: 895585108023.6346
# Аналітичні параметри w: [4766729.24770642  821214.14349519  299983.57107963  695808.52272538]
# Функція втрат для аналітичного рішення: 895585024988.6597
# Різниця між параметрами: [215.32910196  16.1824271  318.6824214  297.44482496]
# Різниця у функції втрат: 83034.97497558594
